# %% [markdown]
# <a href="https://colab.research.google.com/github/AOngomefen/DATA-110-21843/blob/main/Ongomefen_Andrea_DATA110_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ANDREA ONGOMEFEN**
#
# DISPARTIES IN HIV/AIDS DIAGNOSIS BETWEEN TIME, RACE, SEX AND NEIGHBORHOOD
#
# FINAL PROJECT  -- DEC 14 2025

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/content/HIV_AIDS_DIAGNOSES_and_DEMOGRAPHIC.csv')
df.describe()
# Out:
#               YEAR
# count  8976.000000
# mean   2016.360963
# std       3.703894
# min    2010.000000
# 25%    2013.000000
# 50%    2017.000000
# 75%    2020.000000
# max    2021.000000

# %%
df.head() # insight on the start of the df
# Out:
#    YEAR Borough Neighborhood (U.H.F)     SEX           RACE/ETHNICITY  \
# 0  2021     All                  All     All                      All
# 1  2021     All                  All  Female                      All
# 2  2021     All                  All    Male                      All
# 3  2021     All                  All     All  Asian/Pacific\nIslander
# 4  2021     All                  All  Female  Asian/Pacific\nIslander
#
#   TOTAL NUMBER OF HIV DIAGNOSES HIV DIAGNOSES PER 100,000 POPULATION  \
# 0                          1592                                 22.1
# 1                           286                                  7.6
# 2                          1306                                 38.3
# 3                            91                                  8.2
# 4                             9                                  1.5
#
#   TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES  \
# 0                                           306
# ...

# %%
df.tail() # insight on the start of the df
# Out:
#       YEAR Borough Neighborhood (U.H.F)     SEX   RACE/ETHNICITY  \
# 8971  2010     NaN          Willowbrook    Male  Native American
# 8972  2010     NaN          Willowbrook  Female          Unknown
# 8973  2010     NaN          Willowbrook    Male          Unknown
# 8974  2010     NaN          Willowbrook  Female            White
# 8975  2010     NaN          Willowbrook    Male            White
#
#      TOTAL NUMBER OF HIV DIAGNOSES HIV DIAGNOSES PER 100,000 POPULATION  \
# 8971                             0                                    0
# 8972                             0                                    0
# 8973                             0                                    0
# 8974                             0                                    0
# 8975                             1                                  3.6
#
#      TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES  \
# 8971                                             0
# ...

# %% [markdown]
# This dataset from Prof. Rachels Dataset Collection has 11 coloumns and 8900 rows that contain data from 2010 to 2021 on the races, sexes, and neighborhoods diagnosed with HIV and AIDs within the two decade period as well as portion of diagonoses are aids.

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=df, x='YEAR', y='HIV DIAGNOSES PER 100,000 POPULATION', estimator='sum', errorbar=None, palette='mako')
plt.title('AIDS Diagnoses per 100,000 Population per Year', fontsize=14)
plt.xlabel('Year')
plt.ylabel('HIV diagnosis per 100,00 population')
ax = plt.gca()
ax.yaxis.set_major_locator(mtick.MaxNLocator(10))   # limits number of ticks
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /tmp/ipython-input-3177865628.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df, x='YEAR', y='HIV DIAGNOSES PER 100,000 POPULATION', estimator='sum', errorbar=None, palette='mako')

# %% [markdown]
# From the years 2010 to 2020 HIV diagnosis per 100,000 population significantly increased since after quarantine. There was decrease in 2013 - 2017 with a sharp downward trend during covid-19 peak transmission in 2019-2020. HIV diagnosis per 100,000 doubling post-covid.

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='YEAR', y='TOTAL NUMBER OF HIV DIAGNOSES', estimator='sum')
sns.lineplot(data=df, x='YEAR', y='TOTAL NUMBER OF AIDS DIAGNOSES', estimator='sum')
plt.title('Total HIV and AIDS Diagnoses per Year', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Total Diagnoses')
ax.yaxis.set_major_locator(mtick.MaxNLocator(10))   # limits number of ticks
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# This line chart illustrates changes in the total number of HIV diagnoses over a series of years. The x-axis represents time (year), while the y-axis shows the total number of HIV diagnoses. Two lines are displayed to represent different aggregated values in the dataset, allowing for comparison of trends over time. The visualization highlights periods of increase and decrease in diagnoses across the observed time span, including a sharp decline followed by a subsequent increase in the most recent years.

# %%
sns.barplot(
    data=df,
    x='SEX',
    y='HIV DIAGNOSES PER 100,000 POPULATION',
    estimator='mean',
    hue='SEX',
    palette='mako',
    legend=False
)
plt.title('HIV Diagnosis Per 100,000 Population By Sex', fontsize=14)
ax = plt.gca()
ax.yaxis.set_major_locator(mtick.MaxNLocator(10))

# %% [markdown]
# I wanted to see the demographics and boroughs most diagnosed with HIV/ AIDS.

# %%
sns.barplot(
    data=df,
    x='RACE/ETHNICITY',
    y='HIV DIAGNOSES PER 100,000 POPULATION',
    estimator='mean',
    hue='SEX',
    palette='rocket'
)
plt.xticks(rotation=45)
ax = plt.gca()
ax.yaxis.set_major_locator(mtick.MaxNLocator(10))

# %% [markdown]
# This bar chart shows that Black and Hispanic men have the highest rates of HIV diagnoses per 100,000 population, followed by Black and Hispanic women. Across racial and ethnic groups, males consistently exhibit higher diagnosis rates than females. These patterns are observed across the boroughs included in the dataset, highlighting notable disparities by both race/ethnicity and sex.

# %%
plt.figure(figsize=(16, 5))
sns.barplot(data=df, x='RACE/ETHNICITY', y='TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES',
            estimator='sum', errorbar=None, palette='rocket', hue='RACE/ETHNICITY', legend=False)
plt.grid(True, alpha=0.3)
ax = plt.gca()
ax.yaxis.set_major_locator(mtick.MaxNLocator(10))
plt.title('Total Number of Concurrent HIV/AIDS Diagnoses by Race and Ethnicity', fontsize=14)
plt.show()

# %% [markdown]
# The bar chart presents the total number of concurrent HIV/AIDS diagnoses categorized by race and ethnicity. It indicates that the total number of concurrent HIV/AIDS diagnoses varies substantially across racial and ethnic groups. Groups such as Black, White, and Latino/Hispanic populations show higher total counts compared to other groups, while Asian/Pacific Islander, Native American, and Multiracial populations show lower totals. These differences might reflect a combination of population size, access to healthcare, testing practices, and underlying social and structural factors.

# %%
plt.figure(figsize=(13,6))
sns.barplot(data=df, x='Borough', y='TOTAL NUMBER OF HIV DIAGNOSES', estimator='sum', palette='mako' , hue='RACE/ETHNICITY', legend=True)
plt.title('Number of HIV Diagnosis by Race and Borough', fontsize=14)
plt.xlabel("Borough")
plt.ylabel("Number Of HIV Diagnosis")
ax = plt.gca()
ax.yaxis.set_major_locator(mtick.MaxNLocator(10))
plt.show()

# %% [markdown]
# This grouped bar chart illustrates the number of HIV diagnoses across New York City boroughs, broken down by race and ethnicity. The x-axis represents the boroughs (All, Bronx, Brooklyn, Manhattan, Queens, and Staten Island), while the y-axis represents the number of HIV diagnoses. Within each borough, multiple bars are shown to represent different racial and ethnic groups, allowing for comparison both within and across boroughs. Both compartive bar charts show black and latino/hispanic groups leading the charts in all boroughs. But this visualization shows Brooklyn and Manhattan leading the chart.

# %% [markdown]
# 2016 - 2021 CONCURRENT AIDS/HIV DIAGNOSIS ACROSS BORUOGHS

# %% [markdown]
# https://public.tableau.com/views/hiv_aids_diag_interactive_dashbaord/Sheet1?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %% [markdown]
# When examining concurrent HIV/AIDS diagnoses, Black, White, and Latino/Hispanic populations account for the highest total counts, while Asian/Pacific Islander, Native American, and Multiracial groups show lower totals. These differences likely reflect a combination of population size, structural inequalities, access to healthcare, and differences in testing and diagnosis timing.
# Geographically, Brooklyn and Manhattan consistently report higher total numbers of HIV diagnoses compared to other boroughs. Grouped bar charts show that Black and Latino/Hispanic populations lead diagnosis counts within nearly every borough, reinforcing the intersection of racial/ethnic and spatial disparities. The interactive Tableau density map further emphasizes how concurrent HIV/AIDS diagnoses are unevenly distributed across neighborhoods, with concentrations persisting over multiple years.

# %% [markdown]
# Overall, the analysis highlights persistent and intersecting disparities in HIV and AIDS diagnoses across time, demographics, and geography. While overall diagnosis rates declined during portions of the last decade—especially during the COVID-19 pandemic—the post-pandemic increase suggests delayed diagnoses and renewed testing rather than a complete reduction in disease burden. The consistently higher diagnosis rates among Black and Hispanic communities, particularly men, underscore long-standing inequities related to access to care, prevention resources, and broader social determinants of health.
# The geographic concentration of diagnoses in boroughs such as Brooklyn and Manhattan, as well as specific neighborhoods shown in the interactive map, suggests that targeted, place-based public health interventions remain essential. Together, these findings demonstrate the value of combining time-series analysis, demographic comparisons, and spatial visualizations to better understand patterns of HIV and AIDS diagnoses and to inform more equitable public health strategies moving forward.
